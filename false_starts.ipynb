# %%
# !pip install feedparser
# Out:
# Downloading/unpacking feedparser
# ...
#   Running setup.py (path:/home/catherine/ve/afd3/build/feedparser/setup.py) egg_info for package feedparser
#
# ...
#   Running setup.py install for feedparser
#     Fixing build/lib/feedparser.py
#     Skipping implicit fixer: buffer
#     Skipping implicit fixer: idioms
#     Skipping implicit fixer: set_literal
#     Skipping implicit fixer: ws_comma
#     Fixing build/lib/feedparser.py
#     Skipping implicit fixer: buffer
#     Skipping implicit fixer: idioms
#     Skipping implicit fixer: set_literal
#     Skipping implicit fixer: ws_comma
#
# ...
# Cleaning up...

# %%
import feedparser

# %%
# !pip install requests beautifulsoup4
# Out:
# ...
# Cleaning up...

# %%
import requests
result = requests.get('http://www.indiegogo.com/explore?filter_title=dayton')

# %%
result.text[:300]
# Out:
# '<!DOCTYPE html>\n<html>\n<head  >\n  <meta charset="utf-8" />\n<script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"52ee8e3327","applicationID":"265213","transactionName":"J1gLEkINVVQDRUkGQBRbChRVTVBWAlIe","queueTime'

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(result.text)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"52ee8e3327","applicationID":"265213","transactionName":"J1gLEkINVVQDRUkGQBRbChRVTVBWAlIe","queueTime":1,"applicationTime":507,"agent":"js-agent.newrelic.com/nr-632.min.js"}</script>
# ...

# %%
import urllib

# %%
resp = urllib.request.urlopen('https://www.indiegogo.com/explore?filter_title=dayton')

# %%
resp.headers.items()
# Out:
# [('Date', 'Thu, 23 Apr 2015 03:06:25 GMT'),
#  ('Server', 'nginx/1.3.11'),
#  ('Content-Type', 'text/html; charset=utf-8'),
#  ('Status', '200 OK'),
#  ('X-Frame-Options', 'SAMEORIGIN'),
#  ('X-UA-Compatible', 'IE=Edge,chrome=1'),
#  ('ETag', '"745fa7961eec5e5a615bfc5d64343da5"'),
#  ('Cache-Control', 'max-age=0, private, must-revalidate'),
#  ('X-Request-Id', '505b465509f77ea1d77f72dfdaa94c38'),
#  ('X-Runtime', '0.280339'),
#  ('X-Rack-Cache', 'miss'),
#  ('Content-Length', '96223'),
#  ('Accept-Ranges', 'bytes'),
#  ('Via', '1.1 varnish'),
#  ('Age', '0'),
#  ('X-Served-By', 'cache-jfk1032-JFK'),
#  ('X-Cache', 'MISS'),
#  ('X-Cache-Hits', '0'),
#  ('Set-Cookie',
#   'romref=ORG_www_US_XXXX_dir-XXXX_XXXXXXXX_0000_; domain=.indiegogo.com; path=/; expires=Sat, 23-Apr-2016 03:06:25 GMT'),
#  ('Set-Cookie',
#   'visitor_id=ca19bd859411557fb19d9222fe22e6d11682e1ed21ce94a5ebfc20ba3686497e; domain=.indiegogo.com; path=/; expires=Mon, 23-Apr-2035 03:06:25 GMT'),
#  ('Set-Cookie',
# ...

# %%
content = resp.read()

# %%
content.decode('utf8')[:200]
# Out:
# '<!DOCTYPE html>\n<html>\n<head  >\n  <meta charset="utf-8" />\n<script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"'

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(content.decode('utf8'))

# %%
soup.find_all('div', class_='i-project-card')[0]
# Out:
# <div class="i-project-card ">
# <a class="i-category-header" href="/explore/small_business">
# <span class="i-icon i-category-icon i-glyph-icon-22-smallbusiness"></span>
# <span>Small Business</span>
# </a>
# <a class="i-project" href="/projects/harambee-coffee-roasters-co-op-dayton-oh/piad?sa=0&amp;sp=0">
# <div class="i-img" data-src="https://res.cloudinary.com/indiegogo-media-prod-cld/image/upload/c_fill,h_220,w_220/v1421119153/nmh3efv2ci2pwrkyljiy.jpg">
# </div>
# <div class="i-content">
# <div class="i-title">Harambee Coffee Roasters Co-op, Dayton OH</div>
# <div class="i-tagline ">Harambee Coffee Roasters Co-op: A Social Enterprise</div>
# </div>
# <div class="i-stats">
# <span class="currency currency-medium"><span>$310</span><em>USD</em></span>
# <div class="i-progress-bar">
# <div class="i-complete" style="width: 2%"></div>
# </div>
# <div class="i-bottom-row">
# <div class="i-percent">
#             2%
#           </div>
# <div class="i-time-left">
# ...

# %% [markdown]
# ## Kickstarter

# %%
kicks_raw = requests.get('http://www.kickstarter.com/projects/search.json?search=&term=dayton')

# %%
import json

# %%
kicks_raw.headers.keys()
# Out:
# KeysView({'heartbleed': 'NO; see http://heartbleedheader.com', 'x-request-id': 'fa4ab4ea-4a23-4e8c-9a41-97e91df7d1a2', 'set-cookie': 'vis=8d912d95222effa7-f5acb256e82c8e06-0985398131d93ba0v1; path=/; expires=Mon, 23 Apr 2035 09:41:10 -0000; secure, lang=en; path=/; secure, _ksr_session=V25lT0xaZkhEVW1zZHIwT3VTS0tiWjNvNlBEZWF3YW1scFNoRE1PeVg3aUxxYmMxSU1TcWhtNW9ETWhHb2Mxb0UrU3RoL3UwTVBTaU5XaW9QWUdCdXBqZjZ4UkMydjkvSkNVREdpRW5LbGc9LS0reDd3OUM1U05kQi9TaVM4TEk0ZDlBPT0%3D--2ca287a9d8c573bfef34e2773b0f4c8c5f48c172; path=/; secure; HttpOnly, request_time=Thu%2C+23+Apr+2015+09%3A41%3A10+-0000; path=/; secure', 'x-cache': 'MISS', 'via': '1.1 varnish', 'x-content-type-options': 'nosniff', 'x-cache-hits': '0', 'transfer-encoding': 'chunked', 'connection': 'Keep-Alive', 'date': 'Thu, 23 Apr 2015 09:41:10 GMT', 'x-ua-compatible': 'chrome=1', 'status': '200 OK', 'x-served-by': 'cache-jfk1028-JFK', 'x-xss-protection': '1; mode=block', 'accept-ranges': 'bytes', 'keep-alive': 'timeout=10, max=50', 'con
# ...

# %%
print(kicks_raw.content[:100])
# Out:
# b"\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xed\x9d\x8bn\xdcV\xb6\xa6_\x85-\xcc$3\x80K\xc5\xfb\xc5\x80\xd1pl\xa7\x93F\xe2\x18\xb1s2=\xd3\x03as\xefM\xa9\xda\xa5\xa2\xba.Vt\x1a=\x98\x87\x98'\x9c'\x99o\x91\xac\x8bJ%\xd5fI\x96\xcft\x84\x83\x93\xb6\xeaB.\xb2\xc8\xcd\xbd\xbe\xfd\xaf\x7f\xfd\xe3\xe8bZ\xff\xcd\xea"

# %%
response = urllib.request.urlopen('http://www.kickstarter.com/projects/search.json?search=&term=dayton')

# %%
kicks_raw = response.read()

# %%
kicks = json.loads(kicks_raw.decode('utf8'))

# %%
kicks['projects'][0]
# Out:
# {'backers_count': 1,
#  'blurb': 'Development of a hardware-level emulation of long-discontinued Ensoniq samplers and effects processors in VST/AU format for Mac and PC.',
#  'category': {'id': 339,
#   'name': 'Sound',
#   'parent_id': 16,
#   'position': 12,
#   'slug': 'technology/sound',
#   'urls': {'web': {'discover': 'http://www.kickstarter.com/discover/categories/technology/sound'}}},
#  'country': 'US',
#  'created_at': 1426701563,
#  'creator': {'avatar': {'medium': 'https://ksr-ugc.imgix.net/avatars/14567627/profile.original.jpg?v=1429567368&w=160&h=160&fit=crop&auto=format&q=92&s=293a10b95cbcbb938382b74111855e43',
#    'small': 'https://ksr-ugc.imgix.net/avatars/14567627/profile.original.jpg?v=1429567368&w=80&h=80&fit=crop&auto=format&q=92&s=fdda836cb23e014c4abd4bb954ae17df',
#    'thumb': 'https://ksr-ugc.imgix.net/avatars/14567627/profile.original.jpg?v=1429567368&w=40&h=40&fit=crop&auto=format&q=92&s=887f7402dc1f2847c6ed14d4ad928697'},
#   'id': 1779138678,
# ...
